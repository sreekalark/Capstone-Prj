# %%
import requests

# %%
website_url = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

# %% [markdown]
# Convert the website to text format

# %% [markdown]
# Qs 2  : Convert to pandas dataframe with 3 columns

# %%
from bs4 import BeautifulSoup 
soup = BeautifulSoup(website_url,'lxml')

# %%
My_table = soup.find('table',{'class':'wikitable sortable'})
table_rows = My_table.find_all('tr')

l = []
for tr in table_rows:
    td = tr.find_all('td')
    row = [tr.text for tr in td]
    l.append(row)
df = pd.DataFrame(l, columns=['PostalCode', 'Borough', 'Neighborhood'])

df = df.replace('\n','', regex=True)
df.head(20)
# Out:
#    PostalCode           Borough      Neighborhood
# 0        None              None              None
# 1         M1A      Not assigned      Not assigned
# 2         M2A      Not assigned      Not assigned
# 3         M3A        North York         Parkwoods
# 4         M4A        North York  Victoria Village
# 5         M5A  Downtown Toronto      Harbourfront
# 6         M5A  Downtown Toronto       Regent Park
# 7         M6A        North York  Lawrence Heights
# 8         M6A        North York    Lawrence Manor
# 9         M7A      Queen's Park      Not assigned
# 10        M8A      Not assigned      Not assigned
# 11        M9A         Etobicoke  Islington Avenue
# 12        M1B       Scarborough             Rouge
# 13        M1B       Scarborough           Malvern
# 14        M2B      Not assigned      Not assigned
# 15        M3B        North York   Don Mills North
# 16        M4B         East York  Woodbine Gardens
# 17        M4B         East York     Parkview Hill
# ...

# %% [markdown]
# Qs 3b : Ignore cells with a borough that is Not assigned

# %%
df = df[df.Borough!='Not assigned']
df.head(20)
# Out:
#    PostalCode           Borough      Neighborhood
# 0        None              None              None
# 3         M3A        North York         Parkwoods
# 4         M4A        North York  Victoria Village
# 5         M5A  Downtown Toronto      Harbourfront
# 6         M5A  Downtown Toronto       Regent Park
# 7         M6A        North York  Lawrence Heights
# 8         M6A        North York    Lawrence Manor
# 9         M7A      Queen's Park      Not assigned
# 11        M9A         Etobicoke  Islington Avenue
# 12        M1B       Scarborough             Rouge
# 13        M1B       Scarborough           Malvern
# 15        M3B        North York   Don Mills North
# 16        M4B         East York  Woodbine Gardens
# 17        M4B         East York     Parkview Hill
# 18        M5B  Downtown Toronto           Ryerson
# 19        M5B  Downtown Toronto   Garden District
# 20        M6B        North York         Glencairn
# 23        M9B         Etobicoke        Cloverdale
# ...

# %% [markdown]
# Qs 3c : Neighborhoods with same postal code are combined into single row

# %%
df=df.groupby(['PostalCode','Borough'])['Neighborhood'].apply(','.join).reset_index()
df.head(20)
# Out:
#    PostalCode      Borough                                       Neighborhood
# 0         M1B  Scarborough                                      Rouge,Malvern
# 1         M1C  Scarborough               Highland Creek,Rouge Hill,Port Union
# 2         M1E  Scarborough                    Guildwood,Morningside,West Hill
# 3         M1G  Scarborough                                             Woburn
# 4         M1H  Scarborough                                          Cedarbrae
# 5         M1J  Scarborough                                Scarborough Village
# 6         M1K  Scarborough          East Birchmount Park,Ionview,Kennedy Park
# 7         M1L  Scarborough                      Clairlea,Golden Mile,Oakridge
# 8         M1M  Scarborough      Cliffcrest,Cliffside,Scarborough Village West
# 9         M1N  Scarborough                         Birch Cliff,Cliffside West
# 10        M1P  Scarborough  Dorset Park,Scarborough Town Centre,Wexford He...
# ...

# %% [markdown]
# Qs 3d : If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough

# %%
import numpy as np
df['Neighborhood'] = np.where(df['Neighborhood']=='Not assigned', df['Borough'],df['Neighborhood'])
df.head(20)
# Out:
#    PostalCode      Borough                                       Neighborhood
# 0         M1B  Scarborough                                      Rouge,Malvern
# 1         M1C  Scarborough               Highland Creek,Rouge Hill,Port Union
# 2         M1E  Scarborough                    Guildwood,Morningside,West Hill
# 3         M1G  Scarborough                                             Woburn
# 4         M1H  Scarborough                                          Cedarbrae
# 5         M1J  Scarborough                                Scarborough Village
# 6         M1K  Scarborough          East Birchmount Park,Ionview,Kennedy Park
# 7         M1L  Scarborough                      Clairlea,Golden Mile,Oakridge
# 8         M1M  Scarborough      Cliffcrest,Cliffside,Scarborough Village West
# 9         M1N  Scarborough                         Birch Cliff,Cliffside West
# 10        M1P  Scarborough  Dorset Park,Scarborough Town Centre,Wexford He...
# ...

# %% [markdown]
# Shape of dataframe

# %%
df.shape
# Out:
# (103, 3)
